# %%
#bitwise operator
a=14
b=7
print(a<<b)
# Out:
# 1792

# %%
#clear operator
number=[1,2,3,4]
number.clear()
print(number)
# Out:
# []

# %%
#index
numbers=[1,2,3,4]
print(numbers.index(3))
# Out:
# 2

# %%
#count method
numbers=[90,45,69,29,90,69,24,45,29]
print(numbers.count(45))
# Out:
# 2

# %%
#sort method
numbers=[20,30,40,10]
numbers.sort()
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
#sort method
numbers=[10,30,20,40]
numbers.sort(reverse=True)
print(numbers)
# Out:
# [40, 30, 20, 10]

# %%
numbers=[10,20,30,40]
numbers.sort(reverse=True) 
print(numbers)
# Out:
# [40, 30, 20, 10]

# %%
#copy method
a=[1,2,3,4]
b=a.copy()
print(b)
# Out:
# [1, 2, 3, 4]

# %%
numbers=[10,20,30,40,50]
print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::-1])
print(numbers[::-5])
print(numbers[-1::])
print(numbers[::-3])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]
# [50]
# [50]
# [50, 20]
